# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
df1 = pd.read_csv('df1',index_col=0)
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('df2')
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
# automatically it does this
df1['A'].hist()

# %%
df1['A'].plot(kind='hist')

# %%
# or
df1['A'].plot.hist(bins=30)

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df2.plot.area()

# %%
df2.plot.area(alpha=0.4)

# %%
df2.plot.bar()

# %%
df2.plot.bar(stacked=True)

# %%
# hist
df1['A'].plot.hist(bins=100)

# %%
df1.head()
# Out:
#                    A         B         C         D
# 2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df1.plot.scatter(x='A', y='B')

# %%
# c arg is for color or we can also add cmap
df1.plot.scatter(x='A', y='B', c='C', cmap='coolwarm')

# %%
# we can also use size s as args for size 
df1.plot.scatter(x='A', y='B', s=df1['C']*35, alpha=0.45)

# %%
df2.plot.box()

# %%
# for bivariate
df = pd.DataFrame(np.random.randn(1000,2), columns=['a','b'])
df
# Out:
#             a         b
# 0   -0.851294 -1.762815
# 1   -1.440208 -1.329437
# 2   -0.354117  1.270244
# 3    1.538939 -0.089897
# 4    0.339581 -0.996704
# ..        ...       ...
# 995  0.756293 -0.697272
# 996 -1.577270 -1.518582
# 997 -0.461403 -0.358194
# 998 -1.781093  0.121142
# 999 -0.509928 -0.168481
#
# [1000 rows x 2 columns]

# %%
df.plot.hexbin(x='a', y='b')

# %%
df.plot.hexbin(x='a', y='b', gridsize=25)

# %%
df.plot.hexbin(x='a', y='b', gridsize=20, cmap='coolwarm')

# %%
df2.plot.kde()
