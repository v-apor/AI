# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('dark')
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('whitegrid')
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips)

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips)
sns.despine()

# %%
sns.set_style('ticks')
sns.countplot(x='sex', data=tips)
sns.despine(left=True, bottom=True)

# %%
sns.countplot(x='sex', data=tips)

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(12,3))
sns.countplot(x='sex', data=tips)
# Note since seaborn just calls matplot lib, we can use matplotlib's properties

# %%
sns.set_context(context='poster')
sns.countplot(x='sex', data=tips)

# %%
sns.set_context(context='poster', font_scale=2)
sns.countplot(x='sex', data=tips)

# %% [markdown]
# #### Pallets and colors

# %%
sns.set_context(context='notebook')
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex')

# %%
sns.set_context(context='notebook')
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='coolwarm')
# we can goTo matplotlib/ colormap website to check all pallet colors

# %%
sns.lmplot(x='total_bill', y='tip', data=tips, hue='sex', palette='rocket')
